# %%
#import necessary libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ### 2)Load dataset

# %%
data=pd.read_csv('titanic.csv')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ###  3) Perform below visualizations
# #● Univariate Analysis
# #● Bi - Variate Analysis
# #● Multi - Variate Analysis

# %%
# Univariate Analysis

# Bar plot of Age Distribution
sns.countplot(data=data, x='age')
plt.title('Age Distribution')
plt.xlabel('Count')
plt.ylabel('Age')
plt.show()

# %%
# Univariate Analysis

# Bar plot of Deck Class
sns.countplot(data=data, x='deck')
plt.title('Deck Analysis')
plt.xlabel('Type Of Deck')
plt.ylabel('Count')
plt.show()

# %%
# Histogram of age

sns.histplot(data=data, x='age', bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#line plot

plt.plot(data['age'],data['sibsp'])

# %%
# Bivariate Analysis

# Barplot of survival by passenger class
sns.barplot(data=data, x='pclass', y='survived')
plt.title('Survival by Passenger class')
plt.show()

# %%
# Boxplot of fare by class

sns.boxplot(data=data, x='pclass', y='fare')
plt.title('Fare by Class')
plt.show()

# %%
# Boxplot of fare by deck
sns.boxplot(data=data, x='deck', y='fare')
plt.title('Fare by Deck')
plt.show()

# %%
# Multivariate Analysis

# Heatmap of correlation matrix
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_26088\262869352.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %% [markdown]
# ### 4) Perform descriptive statistics on the dataset.

# %%
#calculate basic statistics
statistics = data.describe()
print(statistics)
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.mean()
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_26088\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
data.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
data.median()
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_26088\4184645713.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
data.max()
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_26088\2904433368.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()
# survived             1
# pclass               3
# sex               male
# age               80.0
# sibsp                8
# parch                6
# fare          512.3292
# class            Third
# who              woman
# adult_male        True
# alive              yes
# alone             True
# dtype: object

# %%
data.min()
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_26088\927168777.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.min()
# survived           0
# pclass             1
# sex           female
# age             0.42
# sibsp              0
# parch              0
# fare             0.0
# class          First
# who            child
# adult_male     False
# alive             no
# alone          False
# dtype: object

# %%
data.shape
# Out:
# (891, 15)

# %%
data.kurt()
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_26088\2907027414.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurt()
# survived      -1.775005
# pclass        -1.280015
# age            0.178274
# sibsp         17.880420
# parch          9.778125
# fare          33.398141
# adult_male    -1.827345
# alone         -1.827345
# dtype: float64

# %%
# Distplot
print(sns.distplot(data['age'],color='green'))
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_26088\790203388.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   print(sns.distplot(data['age'],color='green'))
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ### 5) Handle the Missing values.

# %%
print("Missing Values:")
data.isnull().sum()
# Out:
# Missing Values:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### 6)Find the outliers and replace the outliers

# %%
# Select numeric columns for outlier detection and replacement
numeric_cols = ['age', 'fare']

# Find outliers
for col in numeric_cols:
    # Calculate quartiles
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)

# %%
print(Q1)
print(Q3)
# Out:
# 7.9104
# 31.0

# %%
 # Calculate IQR
IQR = Q3 - Q1
IQR
# Out:
# 23.0896

# %%
 # Define outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
print(lower_bound)
print(upper_bound)
# Out:
# -26.724
# 65.6344

# %%
# Create box plots to show outliers
plt.figure(figsize=(6, 4))
for col in numeric_cols:
    sns.boxplot(x=data[col])
    plt.title(f'Box Plot for {col}')
    plt.xlabel(col)
    plt.ylabel('Values')
    plt.show()

# %%
# Finding outliers
outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)]

# %%
# Verify the changes
print("Number of Outliers Found and Replaced:")
print(len(outliers))
# Out:
# Number of Outliers Found and Replaced:
# 116

# %% [markdown]
# ### 7)Check for Categorical columns and perform encoding

# %%
from sklearn.preprocessing import LabelEncoder
lben=LabelEncoder()

# %%
data["embark_town"]=lben.fit_transform(data['embark_town'])

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN            2    no  False
# 1  woman       False    C            0   yes  False
# 2  woman       False  NaN            2   yes   True
# 3  woman       False    C            2   yes  False
# 4    man        True  NaN            2    no   True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  891 non-null    int32
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int32(1), int64(4), object(6)
# memory usage: 88.9+ KB

# %% [markdown]
# ### 8)Split the data into dependent and independent variables.

# %%
# Split the data into dependent and independent variables
X = data.drop('pclass', axis=1)  # Independent variables (features)
y = data['pclass']  # Dependent variable (target)

# %%
X
# Out:
#      survived     sex   age  sibsp  parch     fare embarked   class    who  \
# 0           0    male  22.0      1      0   7.2500        S   Third    man
# 1           1  female  38.0      1      0  71.2833        C   First  woman
# 2           1  female  26.0      0      0   7.9250        S   Third  woman
# 3           1  female  35.0      1      0  53.1000        S   First  woman
# 4           0    male  35.0      0      0   8.0500        S   Third    man
# ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886         0    male  27.0      0      0  13.0000        S  Second    man
# 887         1  female  19.0      0      0  30.0000        S   First  woman
# 888         0  female   NaN      1      2  23.4500        S   Third  woman
# 889         1    male  26.0      0      0  30.0000        C   First    man
# 890         0    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN            2    no  False
# 1         False    C            0   yes  False
# 2         False  NaN            2   yes   True
# 3         False    C            2   yes  False
# 4          True  NaN            2    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN            2    no   True
# 887       False    B            2   yes   True
# 888       False  NaN            2    no  False
# 889        True    C            0   yes   True
# 890        True  NaN            1    no   True
#
# [891 rows x 14 columns]

# %%
y
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %% [markdown]
# ### 9) Scale the independent variables

# %%
# Select the categorical columns for one-hot encoding
categorical_cols = ['sex', 'class']

# Perform one-hot encoding on the categorical variables
encoder = OneHotEncoder(drop='first')
X_encoded = encoder.fit_transform(X[categorical_cols])

# Perform feature scaling on the numerical variables
numeric_cols = X.select_dtypes(include=np.number).columns
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[numeric_cols])

# Concatenate the scaled numerical variables and the encoded categorical variables
X_final = np.concatenate((X_scaled, X_encoded.toarray()), axis=1)

# Print the first few rows of the scaled X
print("Scaled X:")
print(X_final[:5])
# Out:
# Scaled X:
# [[-0.78927234 -0.53037664  0.43279337 -0.47367361 -0.50244517  0.58111394
#    1.          0.          1.        ]
#  [ 1.2669898   0.57183099  0.43279337 -0.47367361  0.78684529 -1.93846038
#    0.          0.          0.        ]
#  [ 1.2669898  -0.25482473 -0.4745452  -0.47367361 -0.48885426  0.58111394
#    0.          0.          1.        ]
#  [ 1.2669898   0.36516706  0.43279337 -0.47367361  0.42073024  0.58111394
#    0.          0.          0.        ]
#  [-0.78927234  0.36516706 -0.4745452  -0.47367361 -0.48633742  0.58111394
#    1.          0.          1.        ]]

# %% [markdown]
# ### 10)Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_final,y,test_size=0.2,random_state=0)

# %%
# Print the shapes of the resulting sets
print("Training set - X shape:", x_train.shape)
print("Training set - y shape:", y_train.shape)
print("Testing set - X shape:", x_test.shape)
print("Testing set - y shape:", y_test.shape)
# Out:
# Training set - X shape: (712, 9)
# Training set - y shape: (712,)
# Testing set - X shape: (179, 9)
# Testing set - y shape: (179,)
